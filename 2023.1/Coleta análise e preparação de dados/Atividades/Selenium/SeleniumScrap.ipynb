# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome('./chromedriver.exe')

# %%
driver.get(r'https://www.scrapethissite.com/pages/simple/')

# %%
# busca=driver.find_element(By.NAME,'q')
# busca.send_keys('pucrs')

# %%
# BotaoPesquisa= driver.find_element(By.NAME,'btnK')
# BotaoPesquisa.click()

# %%
driver.find_elements(By.XPATH, r'//span[@class="country-population"]')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="c1eb0ca0e48d6188e1ab1830953ba102", element="4641273f-db19-4580-9647-bbd63c2bd874")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c1eb0ca0e48d6188e1ab1830953ba102", element="f915004d-0c41-401a-ad28-fe75cd9e9ca6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c1eb0ca0e48d6188e1ab1830953ba102", element="2d85093d-1be7-48c8-a233-69a20f47da60")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c1eb0ca0e48d6188e1ab1830953ba102", element="f4d5d6ce-ed57-489b-a99b-aaec16b39284")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c1eb0ca0e48d6188e1ab1830953ba102", element="fde788c4-06f4-4fd2-8515-dfee9eade47e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c1eb0ca0e48d6188e1ab1830953ba102", element="9e41fd4e-b9d2-4930-b28a-610316d2b86f")>,
# ...
